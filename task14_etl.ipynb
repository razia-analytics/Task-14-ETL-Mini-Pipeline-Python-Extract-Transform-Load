# %%
# !mkdir -p raw processed output

# %%
import pandas as pd

# %%
df = pd.read_csv("raw/retail_sales_dataset.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.isna().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.to_csv("processed/retail_sales_cleaned.csv", index=False)

# %%
df = pd.read_csv("processed/retail_sales_cleaned.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
import re

def standardize_columns(cols):
    return (
        cols.str.lower()
            .str.strip()
            .str.replace(r"[^\w\s]", "", regex=True)
            .str.replace(r"\s+", "_", regex=True)
    )

df.columns = standardize_columns(df.columns)
df.columns
# Out:
# Index(['transaction_id', 'date', 'customer_id', 'gender', 'age',
#        'product_category', 'quantity', 'price_per_unit', 'total_amount'],
#       dtype='object')

# %%
numeric_candidates = [
    c for c in df.columns
    if any(x in c for x in ["sales", "revenue", "price", "amount", "quantity", "units", "profit"])
]

for col in numeric_candidates:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
cat_cols = df.select_dtypes(include="object").columns
df[cat_cols] = df[cat_cols].astype("category")

# %%
date_cols = [c for c in df.columns if "date" in c]

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    1000 non-null   int64
#  1   date              1000 non-null   datetime64[ns]
#  2   customer_id       1000 non-null   category
#  3   gender            1000 non-null   category
#  4   age               1000 non-null   int64
#  5   product_category  1000 non-null   category
#  6   quantity          1000 non-null   int64
#  7   price_per_unit    1000 non-null   int64
#  8   total_amount      1000 non-null   int64
# dtypes: category(3), datetime64[ns](1), int64(5)
# memory usage: 91.3 KB

# %%
df.isna().sum()
# Out:
# transaction_id      0
# date                0
# customer_id         0
# gender              0
# age                 0
# product_category    0
# quantity            0
# price_per_unit      0
# total_amount        0
# dtype: int64

# %%
df.to_csv("processed/retail_sales_standardized.csv", index=False)

# %%
df = pd.read_csv("processed/retail_sales_standardized.csv")
df.head()
# Out:
#    transaction_id        date customer_id  gender  age product_category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    quantity  price_per_unit  total_amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
if "profit" in df.columns:
    df["margin"] = df["profit"]
elif {"revenue", "cost"}.issubset(df.columns):
    df["margin"] = df["revenue"] - df["cost"]
else:
    df["margin"] = df["total_amount"] - (df["price_per_unit"] * df["quantity"])

# %%
df["margin_pct"] = df["margin"] / df["total_amount"]

# %%
high_value_threshold = df["total_amount"].quantile(0.75)
df["is_high_value"] = (df["total_amount"] >= high_value_threshold).astype(int)

# %%
high_margin_threshold = df["margin_pct"].quantile(0.75)
df["is_high_margin"] = (df["margin_pct"] >= high_margin_threshold).astype(int)

# %%
df["is_low_margin"] = (df["margin_pct"] <= 0.10).astype(int)

# %%
if "quantity" in df.columns:
    bulk_threshold = df["quantity"].quantile(0.75)
    df["is_bulk_purchase"] = (df["quantity"] >= bulk_threshold).astype(int)

# %%
if "customer_id" in df.columns:
    df["is_repeat_customer"] = (
        df.groupby("customer_id")["customer_id"].transform("count") > 1
    ).astype(int)

# %%
df[
    ["total_amount", "margin", "margin_pct", "is_high_value", "is_high_margin"]
].head()
# Out:
#    total_amount  margin  margin_pct  is_high_value  is_high_margin
# 0           150       0         0.0              0               1
# 1          1000       0         0.0              1               1
# 2            30       0         0.0              0               1
# 3           500       0         0.0              0               1
# 4           100       0         0.0              0               1

# %%
df.to_csv("processed/retail_sales_features.csv", index=False)

# %%
df = pd.read_csv("processed/retail_sales_features.csv")
df.head()
# Out:
#    transaction_id        date customer_id  gender  age product_category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    quantity  price_per_unit  total_amount  margin  margin_pct  is_high_value  \
# 0         3              50           150       0         0.0              0
# 1         2             500          1000       0         0.0              1
# 2         1              30            30       0         0.0              0
# 3         1             500           500       0         0.0              0
# 4         2              50           100       0         0.0              0
#
#    is_high_margin  is_low_margin  is_bulk_purchase  is_repeat_customer
# 0               1              1                 0                   0
# 1               1              1                 0                   0
# 2               1              1                 0                   0
# 3               1              1                 0                   0
# 4               1              1                 0                   0

# %%
customer_cols = [
    c for c in df.columns
    if c.startswith("customer") or c in ["region", "segment", "is_repeat_customer"]
]

customers = (
    df[customer_cols]
    .drop_duplicates()
    .reset_index(drop=True)
)

customers.head()
# Out:
#   customer_id  is_repeat_customer
# 0     CUST001                   0
# 1     CUST002                   0
# 2     CUST003                   0
# 3     CUST004                   0
# 4     CUST005                   0

# %%
product_cols = [
    c for c in df.columns
    if c.startswith("product") or c in ["category", "sub_category", "is_high_margin"]
]

products = (
    df[product_cols]
    .drop_duplicates()
    .reset_index(drop=True)
)

products.head()
# Out:
#   product_category  is_high_margin
# 0           Beauty               1
# 1         Clothing               1
# 2      Electronics               1

# %%
exclude_cols = set(customer_cols + product_cols)

orders = df[
    [c for c in df.columns if c not in exclude_cols]
].reset_index(drop=True)

orders.head()
# Out:
#    transaction_id        date  gender  age  quantity  price_per_unit  \
# 0               1  2023-11-24    Male   34         3              50
# 1               2  2023-02-27  Female   26         2             500
# 2               3  2023-01-13    Male   50         1              30
# 3               4  2023-05-21    Male   37         1             500
# 4               5  2023-05-06    Male   30         2              50
#
#    total_amount  margin  margin_pct  is_high_value  is_low_margin  \
# 0           150       0         0.0              0              1
# 1          1000       0         0.0              1              1
# 2            30       0         0.0              0              1
# 3           500       0         0.0              0              1
# 4           100       0         0.0              0              1
#
#    is_bulk_purchase
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
print("Customers:", customers.shape)
print("Products:", products.shape)
print("Orders:", orders.shape)
# Out:
# Customers: (1000, 2)
# Products: (3, 2)
# Orders: (1000, 12)

# %%
customers.to_csv("output/customers.csv", index=False)
products.to_csv("output/products.csv", index=False)
orders.to_csv("output/orders.csv", index=False)

# %%
customers = pd.read_csv("output/customers.csv")
products = pd.read_csv("output/products.csv")
orders = pd.read_csv("output/orders.csv")

# %%
customers.head()
# Out:
#   customer_id  is_repeat_customer
# 0     CUST001                   0
# 1     CUST002                   0
# 2     CUST003                   0
# 3     CUST004                   0
# 4     CUST005                   0

# %%
products.head()
# Out:
#   product_category  is_high_margin
# 0           Beauty               1
# 1         Clothing               1
# 2      Electronics               1

# %%
orders.head()
# Out:
#    transaction_id        date  gender  age  quantity  price_per_unit  \
# 0               1  2023-11-24    Male   34         3              50
# 1               2  2023-02-27  Female   26         2             500
# 2               3  2023-01-13    Male   50         1              30
# 3               4  2023-05-21    Male   37         1             500
# 4               5  2023-05-06    Male   30         2              50
#
#    total_amount  margin  margin_pct  is_high_value  is_low_margin  \
# 0           150       0         0.0              0              1
# 1          1000       0         0.0              1              1
# 2            30       0         0.0              0              1
# 3           500       0         0.0              0              1
# 4           100       0         0.0              0              1
#
#    is_bulk_purchase
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %%
# !ls output
# Out:
# customers.csv  orders.csv  products.csv
